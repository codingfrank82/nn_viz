# %% [markdown]
# # Convolutional Neural Networks

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from torchvision.io import read_image

import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print(f"GPU detected: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("No GPU detected, using CPU")

cpu_device = torch.device("cpu")
# Out:
# GPU detected: NVIDIA T400 4GB

# %% [markdown]
# ## Load Image

# %%
def show_image(images, labels):
    fix, axs = plt.subplots(ncols=len(images), squeeze=False, figsize=(12, 6))
    for i, (image, label) in enumerate(zip(images, labels)):
        img = transforms.ToPILImage()(image.to('cpu'))
        axs[0, i].imshow(np.asarray(img), cmap='gray')
        axs[0, i].set_title(label)
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# %%
image_transforms = transforms.Compose([
    transforms.ConvertImageDtype(torch.float),
    transforms.Grayscale()
])

# %%
origin_img = read_image('../../assets/images/lena_std.png')
trans_img = image_transforms(origin_img)
show_image([origin_img, trans_img], ['Original Image', 'Transformed Image'])

# %% [markdown]
# ## Convolutions for Edge Detection

# %% [markdown]
# ### Sobel Edge Detector

# %%
class SobelEdgeDetection(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv_x = nn.Conv2d(1, 1, padding=1, kernel_size=3, bias=False)
        self.conv_y = nn.Conv2d(1, 1, padding=1, kernel_size=3, bias=False)

    def forward(self, x):
        g_x = torch.abs(self.conv_x(x))
        g_y = torch.abs(self.conv_y(x))
        return g_x+g_y

edge_detector = SobelEdgeDetection()
print(edge_detector)
print(edge_detector.conv_x.weight.shape)
# Out:
# SobelEdgeDetection(
#   (conv_x): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (conv_y): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# )
# torch.Size([1, 1, 3, 3])

# %%
sobel_x = torch.tensor([
    [-1, 0, 1],
    [-2, 0, 2],
    [-1, 0, 1]],
    dtype=torch.float32).unsqueeze(0).unsqueeze(0)
sobel_y = torch.tensor([
    [-1, -2, -1],
    [0, 0, 0],
    [1, 2, 1]],
    dtype=torch.float32).unsqueeze(0).unsqueeze(0)

edge_detector.conv_x.weight.data = sobel_x
edge_detector.conv_x.weight.requires_grad = False
edge_detector.conv_y.weight.data = sobel_y
edge_detector.conv_y.weight.requires_grad = False

# %%
filter_image = edge_detector(trans_img)

print(filter_image.shape)
# Out:
# torch.Size([1, 512, 512])

# %%
show_image([origin_img, filter_image], ['Original Image', 'Edge Detection'])

# %% [markdown]
# ## Learning a Kernel

# %%
trans_img = trans_img.to(device)
filter_image = filter_image.to(device)
print(filter_image.device)
# Out:
# cuda:0

# %%
learning_rate = 0.1
num_epochs = 10000

model = SobelEdgeDetection()
model.train()
model.to(device)

loss_fn = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

for _ in tqdm(range(num_epochs)):
    optimizer.zero_grad()
    y_pred = model(trans_img)

    loss = loss_fn(y_pred, filter_image)
    loss.backward()
    optimizer.step()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %% [markdown]
# ### Show Result

# %%
show_image([origin_img, y_pred], ['Original Image', 'Pred Image'])
print('pred soble x: ', model.conv_x.weight)
print('pred soble y: ', model.conv_y.weight)
# Out:
# pred soble x:  Parameter containing:
# tensor([[[[ 1.6291,  0.3754, -0.6821],
#           [ 1.8895,  0.1116, -1.6627],
#           [ 0.6297, -0.5741, -1.7144]]]], device='cuda:0', requires_grad=True)
# pred soble y:  Parameter containing:
# tensor([[[[ 8.2955e-01,  1.5082e+00,  9.9381e-01],
#           [-7.1158e-01, -1.1744e-03,  1.3052e-01],
#           [-7.4955e-01, -1.3533e+00, -6.4669e-01]]]], device='cuda:0',
#        requires_grad=True)

# %% [markdown]
# ### Error analysis

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\coding\.conda\envs\nn_viz\lib\site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\coding\.conda\envs\nn_viz\lib\site-packages (from scikit-image) (1.24.1)
# Requirement already satisfied: scipy>=1.8 in c:\users\coding\.conda\envs\nn_viz\lib\site-packages (from scikit-image) (1.11.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\coding\.conda\envs\nn_viz\lib\site-packages (from scikit-image) (3.0)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\coding\.conda\envs\nn_viz\lib\site-packages (from scikit-image) (9.3.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\coding\.conda\envs\nn_viz\lib\site-packages (from scikit-image) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\coding\.conda\envs\nn_viz\lib\site-packages (from scikit-image) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\coding\.conda\envs\nn_viz\lib\site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\coding\.conda\envs\nn_viz\lib\site-packages (from scikit-image) (23.0)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\coding\.conda\envs\nn_viz\lib\site-packages (from scikit-image) (0.3)

# %%
pred_image = y_pred.detach().cpu().numpy()
true_image = filter_image.detach().cpu().numpy()
print(pred_image.shape)
# Out:
# (1, 512, 512)

# %%
from skimage.metrics import structural_similarity as ssim

# Compute the Mean Squared Error (MSE)
mse = np.mean((pred_image - true_image) ** 2)
print(f'Mean Squared Error (MSE): {mse:.4f}')

# Compute the Structural Similarity Index Measure (SSIM)
ssim_value = ssim(pred_image, true_image, multichannel=True, channel_axis=0, data_range=1)
print(f'Structural Similarity Index Measure (SSIM): {ssim_value}')
# Out:
# Mean Squared Error (MSE): 0.0032
# Structural Similarity Index Measure (SSIM): 0.9611660242080688

# %% [markdown]
# ## References
#
# - [ A guide to convolution arithmetic for deep learning ](https://github.com/vdumoulin/conv_arithmetic)
# - [ Sobel Edge Detector ](https://homepages.inf.ed.ac.uk/rbf/HIPR2/sobel.htm)
